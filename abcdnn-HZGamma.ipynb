# %%
import HZGammaAna
# Out:
# 2023-12-07 18:19:38.011860: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-12-07 18:19:38.011888: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
LRrange3 = [0.00001, 0.00001, 20000, 0]

nafdim=128
depth=2
batchsize=512
seed=101
#ttjjana.rootfile = '/content/gdrive/My Drive/Colab Notebooks/Deep learning - advanced/ABCDnn-delphes/ttjjresult.root'
ttjjana.rootfile = './ttjjresult.root'
ttjjana.train_and_validate(steps=12000, LRrange=LRrange3, minibatch=batchsize, beta1=0.9, beta2=0.999, \
    savedir=f'ttjj_nafnodropout{nafdim}_{batchsize}_depth{depth}_{seed}_9_3_LR3mmd/', nafdim=nafdim, depth=depth, seed=seed, retrain=False, train=True)
# Out:
# [0, 0, 0, 0, 3, 2]
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 9)]          0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 4)            0           input_4[0][0]
# __________________________________________________________________________________________________
# tf.convert_to_tensor_2 (TFOpLam (None, 4)            0           tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.gather_2 (TFOpLamb (None, 4)            0           tf.convert_to_tensor_2[0][0]
# __________________________________________________________________________________________________
# ...
